# %% [markdown]
# # Data Wrangling
#
# ## Table of Contents
#
# * [Data Description](#data-desc)
# * [Data Cleaning](#data-cleaning)
# * [Data Visualization](#data-viz)
# * [Data Transformation](#data-transform)
#     * [Correlations](#corr)
# * [Outputing Processed Data](#data-output)

# %%
import copy
import csv
import folium
import geopandas as gpd
import json
from IPython.display import IFrame, display
import ipywidgets as widgets
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import os
import pandas as pd
import scipy.stats as ss
import seaborn as sn
import sys
import tarfile

sys.path.append("..")
from statshelper import q_q_plot
plt.style.use('dark_background')

# %% [markdown]
# <a id="data-desc"></a>
#
# ***
#
# ## Data Description
#
# I am using data from the Cook County Government Open Data Portal. Specifically, I grabbed the dataset "Archive - Cook County Assessor's Residential Sales Data" which can be found at this link: https://datacatalog.cookcountyil.gov/Property-Taxation/Cook-County-Assessor-s-Residential-Sales-Data/5pge-nu6u The description of the dataset on the site reads:
#
# >This is the data set of residential sales used by the Cook County Assessor in their Computer Assisted Mass Appraisal system used to assess residential property values. This data set contains property information for every arm's-length residential sale in Cook County where class is within a specified list of classes. For disclaimers, see data set narrative at https://datacatalog.cookcountyil.gov/stories/s/p2kt-hk36
#
# >This data set was replaced by the more comprehensive data set Cook County Assessor's Sales.
#
# The "more comprehensive data set" can be found at this link: https://datacatalog.cookcountyil.gov/Property-Taxation/Cook-County-Assessor-s-Sales/93st-4bxh While it has many more records (1.95M compared to 583K), the new dataset only have 11 columns of attributes compared to the 83 in our dataset. Because this dataset is so much richer than the "more comprehensive" one, I have decided to use it over the larger and more recently updated one. To see how this data is used, I recommend checking out the Cook County Assessors Office Gitlab page to see their code (mostly in R): https://gitlab.com/ccao-data-science---modeling .
#
# You may also be interested in this large dataset: https://datacatalog.cookcountyil.gov/Property-Taxation/Cook-County-Assessor-s-Residential-Property-Charac/bcnq-qi2z
#
# You can download the data from there or uncompress `data/Sales.tar`.

# %% [markdown]
# <a id="data-cleaning"></a>
#
# ***
#
# ## Data Cleaning
#
# The data was downloaded to `../data` and we will use the next cell to do a bit of cleaning. First, we load the CSV using pandas and then keep only the rows with "Pure Market Filter" equal to 1 because these are sales that reflect the market. Sales with "Pure Market Filter" equal to 0 means they were not traditional sales with a market price, an example may be a sale within a family, thus using them in our model would introduce error since our objective is to determine the market price of houses. There are also some data entry errors forcing me to filter out any row with a sales price of zero dollars or lower. Lastly, we have a list of 60 columns which we may use for our model, the columns are listed in the variable `drop_if_no_data`. These columns were chosen based on looking at the description of the column on the Open Data Portal and consulting the literature. We drop rows if any of the columns has missing data. The result brings us from 583K rows in the initial dataset to 326,484 rows.

# %%
if not os.path.exists("../data/Cook_County_Assessors_Residential_Sales_Data_2020.csv"):
    my_tar = tarfile.open("../data/Sales.tar")
    my_tar.extractall("../data/")
    my_tar.close()

# %%
# Data from: https://datacatalog.cookcountyil.gov/Property-Taxation/Cook-County-Assessor-s-Residential-Sales-Data/5pge-nu6u
chicago_sales = pd.read_csv("../data/Cook_County_Assessors_Residential_Sales_Data_2020.csv")
chicago_sales = chicago_sales[chicago_sales["Pure Market Filter"] == 1]
chicago_sales = chicago_sales[chicago_sales["Sale Price"] > 0]
chicago_sales = chicago_sales[chicago_sales["Estimate (Building)"] > 0]
chicago_sales = chicago_sales[chicago_sales["Estimate (Land)"] > 0]
drop_if_no_data = [
    'Age',
    'Age Decade',
    'Age Decade Squared', 
    'Age Squared',
    'Apartments',
    'Attic Finish', 
    'Attic Type', 
    'Basement', 
    'Basement Finish',
    'Bedrooms',  
    'Building Square Feet', 
    'Cathedral Ceiling',
    'Census Tract', 
    'Central Air',
    'Central Heating',
    'Deed No.',
    'Design Plan',
    'Estimate (Building)', 
    'Estimate (Land)', 
    'Fireplaces', 
    'Floodplain',
    'Full Baths',
    'Garage 1 Area',
    'Garage 1 Attachment',
    'Garage 1 Material',
    'Garage 1 Size', 
    'Garage 2 Area', 
    'Garage 2 Attachment', 
    'Garage 2 Material',
    'Garage 2 Size', 
    'Garage Indicator',
    'Half Baths', 
    'Land Square Feet',
    'Latitude', 
    'Longitude',
    'Lot Size Squared',
    'Multi Property Indicator',
    'Neighborhood Code',
    "O'Hare Noise",
    'PIN',
    'Porch',
    'Property Class',
    'Pure Market Filter',
    'Road Proximity',
    'Roof Material',
    'Rooms',
    'Sale Date',
    'Sale Half of Year',
    'Sale Half-Year',
    'Sale Price',
    'Sale Quarter',
    'Sale Quarter of Year',
    'Sale Year',
    'Site Desirability',
    'Square root of lot size',
    'Town Code',
    'Town and Neighborhood',
    'Type of Residence',
    'Use',
    'Wall Material'
]
chicago_sales = chicago_sales.dropna(subset=drop_if_no_data, axis=0)

print("Data frame has {} rows and {} columns".format(len(chicago_sales), len(chicago_sales.columns)))
left = set(list(chicago_sales.columns))-set(drop_if_no_data)
left = list(left)
left.sort()
print("Here is a list of rows you did not list in drop_if_no_data: ", left)
chicago_sales.head()
# Out:
# Data frame has 324261 rows and 83 columns
# Here is a list of rows you did not list in drop_if_no_data:  ['Condition, Desirability and Utility', 'Condo Class Factor', 'Condo Strata', 'Construction Quality', 'Improvement Size Squared', 'Large Lot', 'Modeling Group', 'Most Recent Sale', 'Multi Code', 'Multi-Family Indicator', 'Neigborhood Code (mapping)', 'Number of Commercial Units', 'Number of Units', 'Other Heating', 'Other Improvements', 'Percent Ownership', 'Property Address', 'Renovation', 'Repair Condition', 'Sale Month of Year', 'Square root of age', 'Square root of improvement size', 'Total Building Square Feet']
#                PIN  Property Class  Neighborhood Code  Land Square Feet  \
# 2   16094150130000             211                 13            4500.0
# 5    4252000820000             204                100           33898.0
# 8   14322110150000             208                 12            3720.0
# ...

# %% [markdown]
# Next, I dropped a considerable number of rows, in many cases based on the description on the Open Data site. Often the column was dropped because it was a duplicate of other data or only relevant to a slice of the data (i.e. "Total Building Square Feet" only applies to multi-unit residences). There are also many rows with names that look like they would be extremely useful like "Condition, Desirability and Utility" or "Construction Quality", but notes in the column descriptions recommend against using them, saying things like "In general, this column is not useful for analytical purposes." Dropping the columns brings us down to a total of 60 columns.

# %%
cols_to_drop = [
    'Age Decade',
    'Condition, Desirability and Utility', 
    'Condo Class Factor', 
    'Condo Strata', 
    'Construction Quality', 
    'Improvement Size Squared', 
    'Large Lot', 
    'Lot Size Squared',
    'Modeling Group', 
    'Most Recent Sale', 
    'Multi Code', 
    'Multi-Family Indicator', 
    'Neigborhood Code (mapping)', 
    'Number of Commercial Units', 
    'Number of Units', 
    'Other Heating', 
    'Other Improvements', 
    'Percent Ownership', 
    'Property Address', 
    'Renovation', 
    'Repair Condition', 
    'Sale Month of Year', 
    'Square root of age', 
    'Square root of improvement size',
    'Total Building Square Feet',
]
chicago_sales = chicago_sales.drop(cols_to_drop, axis = 1)
print("Data frame has {} rows and {} columns".format(len(chicago_sales), len(chicago_sales.columns)))
# Out:
# Data frame has 324261 rows and 58 columns

# %% [markdown]
# <a id="data-viz"></a>
#
# ***
#
# ## Data Visualization

# %% [markdown]
# Here we use the pandas `describe` function to get an idea of the distribution of the data:

# %%
chicago_sales.describe()
# Out:
#                 PIN  Property Class  Neighborhood Code  Land Square Feet  \
# count  3.242610e+05   324261.000000      324261.000000      3.242610e+05
# mean   1.651628e+13      219.731432         108.992253      7.009554e+03
# std    8.069302e+12       29.243161         100.150467      1.282156e+04
# min    1.011000e+12      202.000000          10.000000      1.490000e+02
# 25%    1.036208e+13      203.000000          34.000000      3.727000e+03
# 50%    1.608316e+13      205.000000          80.000000      5.133000e+03
# 75%    2.311401e+13      211.000000         150.000000      8.000000e+03
# max    3.332302e+13      295.000000         600.000000      2.980767e+06
#
#            Town Code  Type of Residence     Apartments  Wall Material  \
# count  324261.000000      324261.000000  324261.000000  324261.000000
# mean       44.675265           2.118053       0.390352       1.948168
# std        23.754169           1.284953       1.045284       0.782120
# ...

# %% [markdown]
# One of my first questions about the data was "What does the spatial distribution of our data look like?" Below you can see a choropleth map of the number of sales per census tract. This was created with a census tract GeoJSON from the Census Bureau. We process the census tract value to make it string padded with zeros so it can merge with the GeoJSON.
#
# In the map below, color indicates the number of housing sales within the census tract (see the legend in the top-right). The data seems fairly evenly distributed across Chicago, but there seems to be more data near the outskirts of the city. I would assume this is because the census tracts near the outskirts are larger.

# %%
chicago_sales["Census Tract"] = chicago_sales["Census Tract"].astype(int)
tract_counts = chicago_sales["Census Tract"].value_counts()
tract_counts = tract_counts.to_frame()
tract_counts["count"] = tract_counts["Census Tract"]
tract_counts["Census Tract"] = tract_counts.index.astype(str)
tract_counts["Census Tract"] = [x.zfill(6) for x in tract_counts["Census Tract"]]

m = folium.Map(zoom_start=10, location=[41.88, -87.6])
geo_path = "../data/geodata/CookCounty_CensusTract.geojson"

folium.Choropleth(
 geo_data=geo_path,
 data=tract_counts,
 columns=['Census Tract', "count"],
 key_on='feature.properties.TRACTCE',
 nan_fill_color='grey',
 nan_fill_opacity=0.1,
 fill_color='BuPu',
 fill_opacity=0.85,
 line_opacity=0.5,
 legend_name="Housing Sales per Census Tract"
).add_to(m)
m.save('../maps/ChicagoSalesCount.html')

# %%
IFrame(src='../maps/ChicagoSalesCount.html', width=900, height=1000)
# Out:
#         <iframe
#             width="900"
#             height="1000"
#             src="../maps/ChicagoSalesCount.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# For the second map, I wanted to calculate the mean sale price per housing tract. The results are unsurprising with highest values along the lake.

# %%
chicago_sales["Census Tract"] = chicago_sales["Census Tract"].astype(int)
tract_counts = chicago_sales.groupby("Census Tract")["Sale Price"].mean()
tract_counts = tract_counts.to_frame()
tract_counts["Census Tract"] = tract_counts.index.astype(str)
tract_counts["Census Tract"] = [x.zfill(6) for x in tract_counts["Census Tract"]]

m = folium.Map(zoom_start=10, location=[41.88, -87.6])
geo_path = "../data/geodata/CookCounty_CensusTract.geojson"

folium.Choropleth(
 geo_data=geo_path,
 data=tract_counts,
 columns=['Census Tract', "Sale Price"],
 key_on='feature.properties.TRACTCE',
 nan_fill_color='grey',
 nan_fill_opacity=0.1,
 fill_color='BuPu',
 fill_opacity=0.85,
 line_opacity=0.5,
 legend_name="Mean Sale Price per Census Tract"
).add_to(m)
m.save('../maps/ChicagoSalePrice.html')

# %%
IFrame(src='../maps/ChicagoSalePrice.html', width=900, height=1000)
# Out:
#         <iframe
#             width="900"
#             height="1000"
#             src="../maps/ChicagoSalePrice.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# However, we all know about the Modifiable Areal Unit Problem, so I also wanted to map the sale prices for each point in our dataset. To do this, I created a GeoDataFrame from the CSV using the Latitude and Longitude, projected to [UTM Zone 16N](https://epsg.io/26916), and then plotted based on the `Sale Price` variable. Again, we seem a concentration of high sales prices against the lake, but we also see that most of the data falls into the low range of the spectrum. It is clear that this data needs to be transformed to be more useful.

# %%
gdf = gpd.GeoDataFrame(
    copy.deepcopy(chicago_sales), geometry=gpd.points_from_xy(chicago_sales.Longitude, chicago_sales.Latitude))
gdf = gdf.set_crs("EPSG:4326")
gdf = gdf.to_crs("EPSG:26916")

# %%
gdf.plot(column="Sale Price", alpha=0.5, legend=True, figsize=(12,8), markersize=.1)
plt.show()

# %% [markdown]
# Similarly, I was curious about the temporal distribution of the data. Using the "Sale Date" column, I created a histogram of the number of sales which can be seen below. The data runs from the beginning of 2013 to the end of 2019 with peaks in the summer.

# %%
chicago_sales['Sale Date'] = pd.to_datetime(chicago_sales['Sale Date'], format='%m/%d/%Y')
chicago_sales["Sale Date"] = chicago_sales["Sale Date"].astype("datetime64")

fig, ax = plt.subplots(1,1)
ax.hist(chicago_sales["Sale Date"], bins=50, color='lightblue')
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d.%m.%y'))
plt.xticks(rotation=45, ha="right")
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# In the plot below you can see the mean housing price by Sale Quarter. There is clearly seasonality in the data, with the mean housing price rising and falling each year. This could introduce complications into the modeling.

# %%
chicago_sales["Sale Quarter"] = chicago_sales["Sale Quarter"].astype(int)
quarter_sales = chicago_sales.groupby("Sale Quarter")["Sale Price"].mean()
quarter_sales = quarter_sales.to_frame()
quarter_sales.reset_index(inplace=True)
fig, ax = plt.subplots(1,1)
ax.plot(quarter_sales["Sale Quarter"], quarter_sales["Sale Price"])
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# <a id="data-transform"></a>
#
# ***
#
# ## Data Transformation
#
# In the section below, we process the data to make it more readable/useful for out models. The first step you see below is taking a list of attributes that are categorical and transforming them into boolean variables for each category. This could be useful for some machine learning techniques.

# %%
# Categorical --> Boolean (excluding already boolean)
print(sorted(list(chicago_sales.columns)))
categorical = [
    "Attic Finish",
    "Attic Type",
    "Basement",
    "Basement Finish",
    "Cathedral Ceiling",
    #"Census Tract",
    "Central Heating",
    "Design Plan",
    "Fireplaces",
    'Garage 1 Material',
    'Garage 2 Material',
    #"Neighborhood Code",
    "Porch",
    "Property Class",
    "Roof Material",
    'Site Desirability',
    #"Town Code",
    #'Town and Neighborhood',
    "Type of Residence",
    "Wall Material",
]
for col in chicago_sales[categorical]:
    print(col, len(chicago_sales[col].unique()))
    for val in chicago_sales[col].unique():
        print("Bool-{}-{}".format(col, int(val)))
        chicago_sales["Bool-{}-{}".format(col, int(val))] = np.where(chicago_sales[col] == val, 1, 0)
chicago_sales.head()
# Out:
# ['Age', 'Age Decade Squared', 'Age Squared', 'Apartments', 'Attic Finish', 'Attic Type', 'Basement', 'Basement Finish', 'Bedrooms', 'Building Square Feet', 'Cathedral Ceiling', 'Census Tract', 'Central Air', 'Central Heating', 'Deed No.', 'Design Plan', 'Estimate (Building)', 'Estimate (Land)', 'Fireplaces', 'Floodplain', 'Full Baths', 'Garage 1 Area', 'Garage 1 Attachment', 'Garage 1 Material', 'Garage 1 Size', 'Garage 2 Area', 'Garage 2 Attachment', 'Garage 2 Material', 'Garage 2 Size', 'Garage Indicator', 'Half Baths', 'Land Square Feet', 'Latitude', 'Longitude', 'Multi Property Indicator', 'Neighborhood Code', "O'Hare Noise", 'PIN', 'Porch', 'Property Class', 'Pure Market Filter', 'Road Proximity', 'Roof Material', 'Rooms', 'Sale Date', 'Sale Half of Year', 'Sale Half-Year', 'Sale Price', 'Sale Quarter', 'Sale Quarter of Year', 'Sale Year', 'Site Desirability', 'Square root of lot size', 'Town Code', 'Town and Neighborhood', 'Type of Residence', 'Use', 'Wall Material']
# ...

# %% [markdown]
# Next, I wanted to process the quantitative variables that I thought would be most useful for modeling. They are specified in the list `cols_of_interest`. These are also all variables which have to be positive values (a house cannot contain negative area or negative rooms), so I take the absolute value of the data to remove any erroneous negative values.

# %%
cols_of_interest = [
    'Age',
    'Bedrooms',  
    'Building Square Feet', 
    'Estimate (Building)', 
    'Estimate (Land)', 
    'Fireplaces', 
    'Full Baths',
    'Garage 1 Area',
    'Garage 2 Area', 
    'Half Baths', 
    'Land Square Feet',
    'Rooms',
    'Sale Price',
    'Sale Quarter'
]
# Remove erroneous negative values
for col in cols_of_interest:
    chicago_sales[col] = chicago_sales[col].abs()

# %% [markdown]
# Next, we transform many of the variables to try to make them as normal as possible. You can also plot the histogram and Q-Q plot to check the normality. The transformations below are:
#
# * `log` which takes the natural log and
# * `log1p` which calculates $\log(1+x)$. This is useful for when you want to log transform data that contains zeros.

# %%
tdata = chicago_sales.copy()
tdata["Bedrooms"] =  np.log(chicago_sales["Bedrooms"])
tdata["Building Square Feet"] =  np.log(chicago_sales["Building Square Feet"])
tdata["Estimate (Building)"] = np.log(chicago_sales["Estimate (Building)"])
tdata["Estimate (Land)"] = np.log(chicago_sales["Estimate (Land)"])
tdata["Fireplaces"] = np.log1p(chicago_sales["Fireplaces"])
tdata["Full Baths"] = np.log(chicago_sales["Full Baths"])
tdata["Half Baths"] = np.log1p(chicago_sales["Half Baths"])
tdata["Land Square Feet"] = np.log(chicago_sales["Land Square Feet"])
tdata["Rooms"] = np.log(chicago_sales["Rooms"])
tdata["Sale Price"] = np.log(chicago_sales["Sale Price"])

# %% [markdown]
# The dropdown below allows you check each variable for normality using a histogram and Q-Q plot. Some of the data is more normal (`Sale Price`) while others are not very normal at all (`Half Baths`).

# %%
# Normality Checks:
column_dropdown = widgets.Dropdown(
    options=cols_of_interest,
    value="Sale Price",
    description="Column: "
)
display(column_dropdown)
# Out:
# Dropdown(description='Column: ', index=12, options=('Age', 'Bedrooms', 'Building Square Feet', 'Estimate (Buil…

# %%
q_q_plot(tdata[column_dropdown.value])

# %% [markdown]
# The last transformation I applied was normalizing all of these quantitative columns to have mean zero and standard deviation of one.

# %%
# normalize values
normalized_df = tdata.copy()
normalized_df[cols_of_interest] = (tdata[cols_of_interest] - tdata[cols_of_interest].mean(axis=0)) / tdata[cols_of_interest].std(axis=0)
normalized_df.describe()
# Out:
#                 PIN  Property Class  Neighborhood Code  Land Square Feet  \
# count  3.242610e+05   324261.000000      324261.000000      3.242610e+05
# mean   1.651628e+13      219.731432         108.992253      1.289342e-16
# std    8.069302e+12       29.243161         100.150467      1.000000e+00
# min    1.011000e+12      202.000000          10.000000     -5.640353e+00
# 25%    1.036208e+13      203.000000          34.000000     -5.930628e-01
# 50%    1.608316e+13      205.000000          80.000000     -9.124129e-02
# 75%    2.311401e+13      211.000000         150.000000      6.044575e-01
# max    3.332302e+13      295.000000         600.000000      9.886416e+00
#
#            Town Code  Type of Residence     Apartments  Wall Material  \
# count  324261.000000      324261.000000  324261.000000  324261.000000
# mean       44.675265           2.118053       0.390352       1.948168
# std        23.754169           1.284953       1.045284       0.782120
# ...

# %% [markdown]
# Now we can plot the `Sale Price` across Chicago once again and we see much more variation in the value. Plotting the untransformed data was nearly useless, but with the log transform we can see new patterns in the data across space.

# %%
gdf = gpd.GeoDataFrame(
    copy.deepcopy(normalized_df), geometry=gpd.points_from_xy(normalized_df.Longitude, normalized_df.Latitude))
gdf = gdf.set_crs("EPSG:4326")
gdf = gdf.to_crs("EPSG:26916")

# %%
gdf.plot(column="Sale Price", legend=True, alpha=0.5, figsize=(12,8), markersize=.1)
plt.show()

# %% [markdown]
# <a id="corr"></a>
#
# ***
#
# ### Correlations
#
# Now that our data has been transformed, I wanted to explore the distributions and correlations. Below we describe the distribution of the data:

# %%
corr_df = normalized_df[cols_of_interest]
corr_df.describe()
# Out:
#                 Age      Bedrooms  Building Square Feet  Estimate (Building)  \
# count  3.242610e+05  3.242610e+05          3.242610e+05         3.242610e+05
# mean  -7.958685e-17  4.137114e-17         -3.677013e-15        -9.304124e-17
# std    1.000000e+00  1.000000e+00          1.000000e+00         1.000000e+00
# min   -2.077472e+00 -3.513837e+00         -3.056954e+00        -1.016233e+01
# 25%   -6.126325e-01 -2.926810e-01         -7.569215e-01        -6.368033e-01
# 50%   -1.668120e-01 -2.926810e-01         -1.910355e-01        -1.657273e-02
# 75%    7.885178e-01  5.508094e-01          6.588384e-01         5.936153e-01
# max    3.654507e+00  9.679707e+00          5.458316e+00         5.511245e+00
#
#        Estimate (Land)    Fireplaces    Full Baths  Garage 1 Area  \
# count     3.242610e+05  3.242610e+05  3.242610e+05   3.242610e+05
# mean     -1.117470e-15 -1.375678e-16  1.321882e-16   8.015658e-17
# std       1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# ...

# %% [markdown]
# Now we use the built in `corr` ([Pandas Docs](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html)) method to determine the correlations between each variable using Spearman correlation.

# %%
corrMatrix = corr_df.corr(method="spearman")
corrMatrix
# Out:
#                            Age  Bedrooms  Building Square Feet  \
# Age                   1.000000  0.097501             -0.064006
# Bedrooms              0.097501  1.000000              0.758075
# Building Square Feet -0.064006  0.758075              1.000000
# Estimate (Building)  -0.144875  0.417810              0.612335
# Estimate (Land)       0.084011  0.333538              0.417750
# Fireplaces           -0.332925  0.199876              0.384644
# Full Baths           -0.045477  0.663520              0.768967
# Garage 1 Area         0.020555 -0.053815             -0.137689
# Garage 2 Area         0.005576  0.015762              0.019205
# Half Baths           -0.391828  0.128824              0.262125
# Land Square Feet     -0.323056  0.121690              0.111112
# Rooms                 0.047653  0.825894              0.824337
# Sale Price           -0.143765  0.330037              0.498914
# Sale Quarter          0.062711  0.007192              0.009588
#
# ...

# %% [markdown]
# Lastly, we can use the `seaborn` package to plot the correlation matrix for all of these variables:

# %%
sn.heatmap(corrMatrix, annot=True)
fig = plt.gcf()
fig.set_size_inches(24, 12)
plt.show()

# %% [markdown]
# <a id="data-output"></a>
#
# ***
#
#
# ## Outputing Processed Data
#
# Some of the `scikit-learn` packages require that our input data be 32-bit, so we tranform out integers and floats into 32-bit representations. This result is saved to a `pickle` and csv.

# %%
ml_df = copy.deepcopy(normalized_df)
print("Dataframe has {} rows and {} cols".format(len(ml_df), len(ml_df.columns)))

for col in ml_df.columns:
    if col != "PIN":
        if ml_df[col].dtypes == np.int64:
            #print("int64")
            ml_df[col] = ml_df[col].astype("int32")
        elif ml_df[col].dtypes == np.float64:
            ml_df[col] = ml_df[col].astype("float32")
            #print("float64")
        print("Col: {:35s}, Dtype: {}".format(col, ml_df[col].dtypes))
if not os.path.exists("../data/processed"):
    os.mkdir("../data/processed")
ml_df.to_pickle("../data/processed/Cleaned_Chicago_Sales.pkl")
ml_df.to_csv("../data/processed/Cleaned_Chicago_Sales.csv")
# Out:
# Dataframe has 324261 rows and 131 cols
# Col: Property Class                     , Dtype: int32
# Col: Neighborhood Code                  , Dtype: int32
# Col: Land Square Feet                   , Dtype: float32
# Col: Town Code                          , Dtype: int32
# Col: Type of Residence                  , Dtype: float32
# Col: Apartments                         , Dtype: float32
# Col: Wall Material                      , Dtype: float32
# Col: Roof Material                      , Dtype: float32
# Col: Rooms                              , Dtype: float32
# Col: Bedrooms                           , Dtype: float32
# Col: Basement                           , Dtype: float32
# Col: Basement Finish                    , Dtype: float32
# Col: Central Heating                    , Dtype: float32
# Col: Central Air                        , Dtype: float32
# Col: Fireplaces                         , Dtype: float32
# Col: Attic Type                         , Dtype: float32
# ...

# %% [markdown]
# ### FastGWR CSV
#
# If we want to use the [FastGWR](https://github.com/Ziqi-Li/FastGWR) package, it is recommended we use UTM coordinates and our columns have to be in a certain order. The cells below create a GeoDataFrame from our data, transform to UTM Zone 16N, create rows that contain the UTM coordinates, sort the columns in the correct order, and then output the data as a csv.

# %%
gdf = gpd.GeoDataFrame(
    copy.deepcopy(normalized_df), geometry=gpd.points_from_xy(normalized_df.Longitude, normalized_df.Latitude))
gdf = gdf.set_crs("EPSG:4326")
gdf = gdf.to_crs("EPSG:26916")
gdf["utmx"] = gdf['geometry'].x
gdf["utmy"] = gdf['geometry'].y
gdf.head()
# Out:
#                PIN  Property Class  Neighborhood Code  Land Square Feet  \
# 2   16094150130000             211                 13         -0.297580
# 5    4252000820000             204                100          2.868180
# 8   14322110150000             208                 12         -0.596010
# 9   27021200080000             204                 34          1.698873
# 11  13121080620000             204                 42          0.515768
#
#     Town Code  Type of Residence  Apartments  Wall Material  Roof Material  \
# 2          77                3.0         6.0            2.0            2.0
# 5          25                5.0         0.0            2.0            4.0
# 8          74                3.0         0.0            2.0            6.0
# 9          28                1.0         0.0            3.0            1.0
# 11         71                1.0         0.0            2.0            1.0
#
#        Rooms  ...  Bool-Type of Residence-8  Bool-Type of Residence-7  \
# ...

# %%
#print(list(normalized_df.columns))
fastgwr_column_order = [
    "utmx",
    "utmy",
    "Sale Price",
    'Age',
    'Bedrooms',  
    'Building Square Feet', 
    'Estimate (Building)', 
    'Estimate (Land)', 
    'Fireplaces', 
    'Full Baths',
    'Garage 1 Area',
    'Garage 2 Area', 
    'Half Baths', 
    'Land Square Feet',
    'Rooms',
    'Sale Quarter'
]
fastgwr_df = gdf[fastgwr_column_order]
fastgwr_df = fastgwr_df.reset_index(drop=True)
fastgwr_df.head()
# Out:
#             utmx          utmy  Sale Price       Age  Bedrooms  \
# 0  437681.805280  4.637169e+06   -0.971650  0.661141  3.771966
# 1  435491.294812  4.660197e+06    2.168769 -0.166812  0.550809
# 2  446042.183284  4.641371e+06    3.164646 -1.981939  1.205071
# 3  430518.043161  4.610285e+06    0.612891 -1.185830 -0.292681
# 4  441804.354822  4.647907e+06    1.133576 -0.134968  1.205071
#
#    Building Square Feet  Estimate (Building)  Estimate (Land)  Fireplaces  \
# 0              3.346712             0.198220        -0.355161   -0.599533
# 1              2.344955             2.008599         3.033816    2.605121
# 2              2.148512             3.927666         3.365584    2.605121
# 3              0.704653             0.066933         1.269788    1.422378
# 4              1.007764             0.953069         1.661313    1.422378
#
#    Full Baths  Garage 1 Area  Garage 2 Area  Half Baths  Land Square Feet  \
# ...

# %%
fastgwr_df.to_csv("../data/processed/FastGWR_Chicago_Sales.csv", index=False)
